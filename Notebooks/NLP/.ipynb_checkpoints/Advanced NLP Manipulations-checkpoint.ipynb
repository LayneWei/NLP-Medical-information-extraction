# %%
import nltk
import csv
from nltk.tokenize import word_tokenize
from string import punctuation
import re
import spacy
from spacy import displacy
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
import stanfordnlp
import pandas as pd
import csv

STOP_WORDS = set(ENGLISH_STOP_WORDS)
STOP_WORDS.remove('no')
STOP_WORDS.remove('not')
#STOP_WORDS.remove('of')
print(STOP_WORDS)
# Out:
# {'until', 'during', 'ever', 'show', 'detail', 'made', 'nobody', 'thin', 'hasnt', 'meanwhile', 'can', 'toward', 'along', 'also', 'its', 'one', 'noone', 'too', 'mine', 'whereby', 'please', 'seeming', 'co', 'although', 'nowhere', 'five', 'after', 'behind', 'against', 'either', 'con', 'get', 'several', 'some', 'call', 'up', 'latter', 'itself', 'do', 'elsewhere', 'in', 'should', 'herein', 'six', 'seem', 'besides', 'neither', 'cannot', 'has', 'will', 'done', 'every', 'became', 'perhaps', 'from', 'thru', 'upon', 'anywhere', 'very', 'now', 'been', 'his', 'go', 'by', 'rather', 'keep', 'through', 'inc', 'forty', 'thence', 'beyond', 'indeed', 'why', 'we', 'another', 'everyone', 'or', 'since', 'most', 'four', 'seems', 'as', 'would', 'take', 'whatever', 'formerly', 'he', 'via', 'the', 'but', 'interest', 'none', 'then', 'back', 'somehow', 'else', 'enough', 'everything', 'into', 'often', 'sixty', 'therein', 'between', 'twelve', 'describe', 'how', 'someone', 'while', 'seemed', 'hundred', 'move', 'about', 'side', 'an', 'among', 'twenty', 'me', 'where', 'hereby', 'two', 'namely', 'give', 'always', 'ie', 'thick', 'himself', 'whereas', 'fire', 'across', 'becoming', 'thereafter', 'full', 'without', 'nine', 'are', 'whose', 'wherein', 'if', 'so', 'eleven', 'hereafter', 'next', 'thus', 'below', 'only', 'be', 'almost', 'is', 'your', 'see', 'however', 'three', 'was', 'whither', 'becomes', 'again', 'though', 'de', 'such', 'any', 'empty', 'become', 'eg', 'us', 'with', 'whence', 'and', 'own', 'bottom', 'once', 'above', 'cant', 'third', 'together', 'couldnt', 'am', 'they', 'their', 'anyhow', 'whether', 'nevertheless', 'amoungst', 'found', 'sometimes', 'our', 'serious', 'fifty', 'alone', 'much', 'never', 'per', 'anyone', 'afterwards', 'etc', 'whenever', 'wherever', 'many', 'were', 'system', 'anyway', 'fifteen', 'sometime', 'former', 'to', 'because', 'before', 'throughout', 'other', 'last', 'yourselves', 'amount', 'beside', 'name', 'had', 'hers', 'who', 'least', 'ours', 'fill', 'whole', 'off', 'over', 'have', 'already', 'even', 'myself', 'my', 'whereafter', 'may', 'could', 'except', 'them', 'everywhere', 'around', 'un', 'bill', 'same', 'for', 'nothing', 'under', 'find', 'less', 'nor', 'first', 'ten', 'eight', 'her', 'otherwise', 're', 'which', 'on', 'yet', 'towards', 'must', 'i', 'of', 'a', 'ltd', 'this', 'out', 'moreover', 'hence', 'you', 'it', 'top', 'all', 'somewhere', 'cry', 'these', 'yourself', 'thereupon', 'both', 'whereupon', 'at', 'latterly', 'being', 'that', 'few', 'down', 'still', 'mostly', 'him', 'others', 'than', 'sincere', 'might', 'something', 'yours', 'those', 'ourselves', 'what', 'there', 'whom', 'mill', 'hereupon', 'whoever', 'herself', 'beforehand', 'part', 'therefore', 'anything', 'she', 'more', 'within', 'thereby', 'themselves', 'amongst', 'front', 'onto', 'due', 'when', 'here', 'each', 'well', 'further', 'put'}

# %%
nlp = stanfordnlp.Pipeline(processors = "tokenize,mwt,pos,depparse")
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': 'C:\\Users\\schaa\\stanfordnlp_resources\\en_ewt_models\\en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': 'C:\\Users\\schaa\\stanfordnlp_resources\\en_ewt_models\\en_ewt_tagger.pt', 'pretrain_path': 'C:\\Users\\schaa\\stanfordnlp_resources\\en_ewt_models\\en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: depparse
# With settings:
# {'model_path': 'C:\\Users\\schaa\\stanfordnlp_resources\\en_ewt_models\\en_ewt_parser.pt', 'pretrain_path': 'C:\\Users\\schaa\\stanfordnlp_resources\\en_ewt_models\\en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
abbreviation_path = 'concept_abbreviation.txt'
with open(abbreviation_path, 'r') as dictionary:
    abbreviations_dic = {}
    for line in dictionary:
        if len(line)>1:
            line=line.split('-',1)
            abbreviations_dic[line[0].rstrip().lower()] = line[1].lstrip().lower()
            
digit_pattern = '\d+'
date_pattern = r"[\d]{1,2}/[\d]{1,2}/[\d]{2,4}"
time_pattern = r"[\d]{1,2}:[\d]{1,2}:[\d]{1,2}"
DIGIT_SIGN = '/DIGIT'
DATE_SIGN = 'DATE'
TIME_SIGN = 'TIME'
apas_error = '&apos;'

##find way to replace dates by today for example -> see what they depend on!!

# %%
filepath = 'cTAKES archive/clinical-11.txt'

text = []
with open(filepath, 'r') as file:
    data = file.read()
    
data = re.sub(date_pattern, DATE_SIGN, data)
data = re.sub(time_pattern, TIME_SIGN, data)
#data = re.sub(digit_pattern, DIGIT_SIGN, data)
data = re.sub(apas_error, "'", data)
print(data)
# Out:
# 025897906
# CTMC
# 81515170
# 481064
# DATE TIME AM
# Discharge Summary
# Signed
# DIS
# Admission Date :
# DATE
# Report Status :
# Signed
# Discharge Date :
# DATE
# DISCHARGE DIAGNOSIS :
# METASTATIC CERVICAL CARCINOMA .
# SECONDARY DIAGNOSES INCLUDE PERICARDIAL EFFUSION , PULMONARY LYMPHANGITIC SPREAD , AND LIVER AND SPLEEN METASTASES .
# OPERATIONS AND PROCEDURES :
# Echocardiogram times two .
# HISTORY OF PRESENT ILLNESS :
# Patient is a 28 year old gravida IV , para 2 with metastatic cervical cancer admitted with a question of malignant pericardial effusion .
# Patient underwent a total abdominal hysterectomy in 02/90 for a 4x3.6x2 cm cervical mass felt to be a fibroid at Vanor .
# Pathology revealed poorly differentiated squamous cell carcinoma of the cervix with spots of vaginal margins and metastatic squamous cell carcinoma in the cardinal ligaments with extensive lymphatic invasion .
# Patient was felt to have stage 2B disease and post-operatively , she was treated with intracavitary and external beam radiation therapy and low dose Cisplatin .
# On ultrasound in 02/91 , the patient was found to have bilateral cystic adnexal masses confirmed on physical examination .
# She underwent exploratory laparotomy and had a bilateral salpingo-oophorectomy and appendectomy .
# Pathology was negative for tumor and showed peritubal and periovarian adhesions .
# The patient now presents with a three to four week history of shortness of breath and a dry non-productive cough .
# She was evaluated by Dr. Mielke , a Pulmonologist , who found her to be wheezing and performed pulmonary function tests which showed an FEV1 of 1.1 and an FVC of 1.8 .
# She was admitted to Weekscook University Medical Center with a diagnosis of possible asthma .
# Room air arterial blood gas showed a pO2 of 56 , a pCO2 of 35 , and a pH of 7.52 .
# EKG showed sinus tachycardia at 100 and echo revealed pericardial effusion , a 10 mm pulsus paradoxus was noted , and no evidence of tamponade .
# Given the patient 's history of cervical cancer , the pericardial effusion was felt most likely to be malignant .
# She was therefore transferred to the Retelk County Medical Center for further care .
# PAST MEDICAL HISTORY :
# As above .
# PAST SURGICAL HISTORY :
# 02/90 , total abdominal hysterectomy complicated by ureteral transection with right ureteral tube placed for six weeks , stent tube placed in left ureter six weeks prior to admission for a hydronephrosis post , in 03/91 , bilateral salpingo-oophorectomy and appendectomy .
# CURRENT MEDICATIONS :
# Prednisone 20 mg p.o. q.a.m. with 10 mg p.o. q.p.m. , Uniphyl 400 mg p.o. q.d. , Augmentin 250 p.o. t.i.d. , Estrase 2 mg p.o. q.d. , MS Contin 30 mg q.12h. , and Morphine p.r.n.
# PHYSICAL EXAMINATION :
# Emaciated white female in mild respiratory distress .
# Temperature was 98.1 , heart rate 116 , blood pressure 120/68 , and room air O2 saturation was 93% .
# HEENT :
# Dry mucous membranes and myotic pupils .
# NECK :
# No lymphadenopathy .
# CHEST :
# Few inspiratory wheezes and no rhonchi .
# HEART :
# Regular rate and rhythm with tachycardia and no rubs or murmur .
# ABDOMEN :
# Well healed Pfannenstiel scars and no masses .
# PELVIC :
# No masses .
# RECTAL :
# No masses and guaiac negative .
# EXTREMITIES :
# No edema or cyanosis .
# LABORATORY EXAMINATION :
# Hematocrit was 40 , white count was 21 , and platelet count of 723,000 .
# PT and PTT were 12 and 26 .
# Electrolytes were within normal limits , liver function tests within normal limits , and EKG showed a heart rate of 128 , axis 73 , and possible ectopic P .
# HOSPITAL COURSE :
# The patient was admitted for a new pericardial effusion which was felt most likely to be secondary to metastatic cervical cancer .
# There was no evidence of tamponade .
# An echocardiogram was scheduled and Cardiology was consulted .
# Echocardiogram showed moderate anterior pericardial effusion of approximately 600 cc with diastolic indications of the right ventricle and low velocity paradox .
# Cardiology did not feel that tamponade at this time was a concern and that a tap need not be performed .
# She continued to have pulmonary wheezing , unknown origin , without history of asthma .
# Her steroids were tapered and Pulmonary was consulted who recommended a CT scan of the chest to evaluate the lung parenchyma , induce sputum for CBC , arterial blood gas , continuing of the beta agonist inhalers , and trial of steroid inhalers .
# They felt it was most likely a malignant lymphangitic spread with pericardial involvement versus infectious , other cardiovascular causes , or viral bronchiolitis .
# She had pulmonary function tests repeated which showed an FEV1 of 36% of predicted and FVC of 56% of predicted .
# Room air arterial blood gas showed a pH of 7.45 , pO2 of 63 , a pCO2 of 41 , and fairly significant AA gradient .
# She was continued on two liters of oxygen awaiting her CT scan on 06/14 and she developed a new junctional rhythm with a question of a new rub versus murmur on examination .
# Cardiology felt she had a rub and her pulsus was still 10 .
# EKG showed an ectopic low atrial P and they thought she was still stable without evidence of tamponade .
# She should have a follow-up echocardiogram .
# Echocardiogram showed left ventricle at the upper limits of normal for size , low normal function , moderate to mild effusion with pericardial pressures exceeding right atrial pressures , and right ventricular pressures at various points of patient 's cycle without any change in the effusion from 06/11 .
# Thoracic Surgery was also consulted and they felt that there was no need for a pericardial window at the time .
# She should be continued with pulmonary oximetry testing .
# She underwent her CT scan .
# This showed lymphangitic spread of cancer in the chest , question of pulmonary nodules in the chest , pericardial effusion , multiple liver metastases , decreased function of the left kidney , dilated left intrarenal collecting system and proximal ureter , and periaortic lymphadenopathy .
# Pulmonary felt this was consistent also with lymphangitic spread and they did not feel that a bronchoscopy would be of any assistance at this time .
# Chemotherapy for metastatic cervical cancer was discussed with the patient and she was started on 5-FU 800 mg per meter squared days 06/18 , 06/19 , and 06/20 .
# She also received Cisplatin 35 per meter squared on 06/19 and Ifex and Mesna on 06/18 .
# She was noted , on 06/16 , to have numerous erythematous maculopapules on her back and chest .
# Dermatology was consulted and they felt that this was most likely steroid acne .
# They therefore felt a rapid steroid taper was indicated and topical Erythromycin if desired by the patient .
# The patient 's shortness of breath and wheezing continued but without change .
# Her cardiac examination remained the same and there continued to be no evidence of tamponade .
# Cardiology felt that follow-up echo was indicated on 06/18 as she had another echocardiogram which showed no change or evidence of tamponade .
# They therefore felt that she could be continued to be followed by examination .
# She had some mental status changes with confusion and hallucinations on 06/18 originating from narcotics versus decreased pO2 .
# The Ifex was held as it was felt that it could have precipitated the mental status changes and that she was to receive no further Ifex .
# She had no further hallucinations since stopping the Ifex .
# Psychiatry was also consulted to help her with the changes she was feeling since her new diagnosis .
# She was hooked up with support services in Collot Ln , Dugo , Indiana 68961 for further counselling and given Xanax for symptoms of anxiety .
# She continued to have no change in her shortness of breath or cardiac examination and was discharged home on DATE after completing her 5-FU and Cisplatin chemotherapy .
# DISPOSITION :
# She will be followed by Dr. Mielke and home care services .
# DISCHARGE MEDICATIONS :
# Premarin 0.625 q.d. , Proventil Inhaler two puffs q.i.d. , Beclovent four puffs b.i.d. , Colace 100 mg p.o. t.i.d. , MS Contin 30 mg p.o. t.i.d. , Elavil 25 mg p.o. q.h.s. , Trilisate 750 mg p.o. b.i.d. , MS Elixir 100 mg p.o. q.2h. p.r.n. , Robitussin with Codeine 5 cc p.o. q.2h. , and home O2 two liters via nasal prong with increase to four liters as needed for symptoms p.r.n.
# ZQ233/5272 EARLLAMARG S. MIELKE , M.D. RP75
# D :
# DATE
# Batch :
# 8600
# Report :
# J4678A87
# T :
# DATE
# Dicatated By :
# SONRELLE LOUELLPASCGACH , M.D. EH41

# %%
tokens = word_tokenize(data)
for i in range(len(tokens)):
    if tokens[i].lower() in abbreviations_dic:
        for j,n in enumerate(abbreviations_dic[tokens[i].lower()].split()):
            tokens.insert(i+j+1,n)
        del tokens[i]

print(tokens)
# Out:
# ['025897906', 'CTMC', '81515170', '481064', 'DATE', 'TIME', 'AM', 'Discharge', 'Summary', 'Signed', 'DIS', 'Admission', 'Date', ':', 'DATE', 'Report', 'Status', ':', 'Signed', 'Discharge', 'Date', ':', 'DATE', 'DISCHARGE', 'DIAGNOSIS', ':', 'METASTATIC', 'CERVICAL', 'CARCINOMA', '.', 'SECONDARY', 'DIAGNOSES', 'INCLUDE', 'PERICARDIAL', 'EFFUSION', ',', 'PULMONARY', 'LYMPHANGITIC', 'SPREAD', ',', 'axillary', 'node', 'dissection', 'LIVER', 'axillary', 'node', 'dissection', 'SPLEEN', 'METASTASES', '.', 'OPERATIONS', 'axillary', 'node', 'dissection', 'PROCEDURES', ':', 'Echocardiogram', 'times', 'two', '.', 'HISTORY', 'OF', 'PRESENT', 'ILLNESS', ':', 'Patient', 'is', 'mibi', '-', 'adenosine', 'mibi', '28', 'year', 'old', 'gravida', 'intravenous', ',', 'para', '2', 'with', 'metastatic', 'cervical', 'cancer', 'admitted', 'with', 'mibi', '-', 'adenosine', 'mibi', 'question', 'of', 'malignant', 'pericardial', 'effusion', '.', 'Patient', 'underwent', 'mibi', '-', 'adenosine', 'mibi', 'total', 'abdominal', 'hysterectomy', 'in', '02/90', 'for', 'mibi', '-', 'adenosine', 'mibi', '4x3.6x2', 'cardiomegaly', 'cervical', 'mass', 'felt', 'to', 'bacterial', 'endocarditis;', 'also', 'barium', 'enema', 'mibi', '-', 'adenosine', 'mibi', 'fibroid', 'at', 'Vanor', '.', 'Pathology', 'revealed', 'poorly', 'differentiated', 'squamous', 'cell', 'carcinoma', 'of', 'the', 'cervix', 'with', 'spots', 'of', 'vaginal', 'margins', 'axillary', 'node', 'dissection', 'metastatic', 'squamous', 'cell', 'carcinoma', 'in', 'the', 'cardinal', 'ligaments', 'with', 'extensive', 'lymphatic', 'invasion', '.', 'Patient', 'was', 'felt', 'to', 'have', 'stage', '2B', 'disease', 'axillary', 'node', 'dissection', 'post-operatively', ',', 'she', 'was', 'treated', 'with', 'intracavitary', 'axillary', 'node', 'dissection', 'external', 'beam', 'radiation', 'therapy', 'axillary', 'node', 'dissection', 'low', 'dose', 'Cisplatin', '.', 'optic', 'nerve;', 'over', 'night', 'ultrasound', 'in', '02/91', ',', 'the', 'patient', 'was', 'found', 'to', 'have', 'bilateral', 'cystic', 'adnexal', 'masses', 'confirmed', 'optic', 'nerve;', 'over', 'night', 'physical', 'examination', '.', 'She', 'underwent', 'exploratory', 'laparotomy', 'axillary', 'node', 'dissection', 'had', 'mibi', '-', 'adenosine', 'mibi', 'bilateral', 'salpingo-oophorectomy', 'axillary', 'node', 'dissection', 'appendectomy', '.', 'Pathology', 'was', 'negative', 'for', 'tumor', 'axillary', 'node', 'dissection', 'showed', 'peritubal', 'axillary', 'node', 'dissection', 'periovarian', 'adhesions', '.', 'The', 'patient', 'now', 'presents', 'with', 'mibi', '-', 'adenosine', 'mibi', 'three', 'to', 'four', 'week', 'history', 'of', 'shortness', 'of', 'breath', 'axillary', 'node', 'dissection', 'mibi', '-', 'adenosine', 'mibi', 'dry', 'non-productive', 'cough', '.', 'She', 'was', 'evaluated', 'by', 'Dr.', 'Mielke', ',', 'mibi', '-', 'adenosine', 'mibi', 'Pulmonologist', ',', 'who', 'found', 'her', 'to', 'bacterial', 'endocarditis;', 'also', 'barium', 'enema', 'wheezing', 'axillary', 'node', 'dissection', 'performed', 'pulmonary', 'function', 'tests', 'which', 'showed', 'an', 'forced', 'expiratory', 'volume', '1', 'second', 'of', '1.1', 'axillary', 'node', 'dissection', 'an', 'FVC', 'of', '1.8', '.', 'She', 'was', 'admitted', 'to', 'Weekscook', 'University', 'Medical', 'Center', 'with', 'mibi', '-', 'adenosine', 'mibi', 'diagnosis', 'of', 'possible', 'asthma', '.', 'Room', 'air', 'arterial', 'blood', 'group', 'mibi', '-', 'adenosine', 'mibi', 'strep;', 'guaiac', 'allergies;', 'also', 'acute', 'lymphocytic', 'leukemia', 'stools', 'showed', 'mibi', '-', 'adenosine', 'mibi', 'pO2', 'of', '56', ',', 'mibi', '-', 'adenosine', 'mibi', 'pCO2', 'of', '35', ',', 'axillary', 'node', 'dissection', 'mibi', '-', 'adenosine', 'mibi', 'pin', 'hole', 'of', '7.52', '.', 'electrocardiogram', '(also', 'known', 'aortic', 'stenosis;', 'also', 'anklyosing', 'spondylitis', 'ecg)', 'showed', 'sinus', 'tachycardia', 'at', '100', 'axillary', 'node', 'dissection', ' ...

# %%
# tagged_review = nltk.pos_tag(tokens[20:])
# tagged_review

# %%
doc = nlp(data)
# Out:
# ..\aten\src\ATen\native\LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
pos_dict = {
'CC': 'coordinating conjunction','CD': 'cardinal digit','DT': 'determiner',
'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
'FW': 'foreign word','IN':  'preposition/subordinating conjunction','JJ': 'adjective \'big\'',
'JJR': 'adjective, comparative \'bigger\'','JJS': 'adjective, superlative \'biggest\'',
'LS': 'list marker 1)','MD': 'modal could, will','NN': 'noun, singular \'desk\'',
'NNS': 'noun plural \'desks\'','NNP': 'proper noun, singular \'Harrison\'',
'NNPS': 'proper noun, plural \'Americans\'','PDT': 'predeterminer \'all the kids\'',
'POS': 'possessive ending parent\'s','PRP': 'personal pronoun I, he, she',
'PRP$': 'possessive pronoun my, his, hers','RB': 'adverb very, silently,',
'RBR': 'adverb, comparative better','RBS': 'adverb, superlative best',
'RP': 'particle give up','TO': 'to go \'to\' the store.','UH': 'interjection errrrrrrrm',
'VB': 'verb, base form take','VBD': 'verb, past tense took',
'VBG': 'verb, gerund/present participle taking','VBN': 'verb, past participle taken',
'VBP': 'verb, sing. present, non-3d take','VBZ': 'verb, 3rd person sing. present takes',
'WDT': 'wh-determiner which','WP': 'wh-pronoun who, what','WP$': 'possessive wh-pronoun whose',
'WRB': 'wh-abverb where, when','QF' : 'quantifier, bahut, thoda, kam (Hindi)','VM' : 'main verb',
'PSP' : 'postposition, common in indian langs','DEM' : 'demonstrative, common in indian langs'
}

#extract parts of speech
def extract_pos(sentences):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    #return a dataframe of pos and text
    return pd.DataFrame(parsed_text)

#extract pos
extract_pos(doc.sentences[10:12])
# Out:
#             word   pos                                    exp
# 0             On    IN  preposition/subordinating conjunction
# 1     ultrasound    NN                  noun, singular 'desk'
# 2             in    IN  preposition/subordinating conjunction
# 3          02/91    CD                         cardinal digit
# 4              ,     ,                                     NA
# 5            the    DT                             determiner
# 6        patient    NN                  noun, singular 'desk'
# 7            was   VBD                  verb, past tense took
# 8          found   VBN            verb, past participle taken
# 9             to    TO                  to go 'to' the store.
# 10          have    VB                   verb, base form take
# 11     bilateral    JJ                        adjective 'big'
# 12        cystic    JJ                        adjective 'big'
# 13       adnexal    JJ                        adjective 'big'
# 14        masses   NNS                    noun plural 'desks'
# 15     confirmed   VBN            verb, past participle taken
# 16            on    IN  preposition/subordinating conjunction
# 17      physical    JJ                        adjective 'big'
# 18   examination    NN                  noun, singular 'desk'
# 19             .     .                                     NA
# 20           She   PRP            personal pronoun I, he, she
# 21     underwent   VBD                  verb, past tense took
# 22   exploratory    JJ                        adjective 'big'
# 23    laparotomy    NN                  noun, singular 'desk'
# 24           and    CC               coordinating conjunction
# 25           had   VBD                  verb, past tense took
# 26             a    DT                             determiner
# 27     bilateral    JJ                        adjective 'big'
# 28      salpingo    NN                  noun, singular 'desk'
# 29             -  HYPH                                     NA
# 30  oophorectomy    NN                  noun, singular 'desk'
# 31           and    CC               coordinating conjunction
# 32  appendectomy    NN                  noun, singular 'desk'
# 33             .     .                                     NA

# %%
for word in doc.sentences[5].words:
    print(word.text)
# Out:
# HISTORY
# OF
# PRESENT
# ILLNESS
# :

# %%
for sent in doc.sentences:
    sent.print_dependencies()
    print('-----------------')
    
    
##have to check both for words that the concept is dependent on and for words that depend on the concept
##e.g. negative for tumours -> tumours depends on negative here
# Out:
# ('025897906', '0', 'root')
# ('CTMC', '3', 'compound')
# ('81515170', '1', 'appos')
# ('481064', '6', 'nummod')
# ('DATE', '6', 'compound')
# ('TIME', '9', 'compound')
# ('AM', '9', 'compound')
# ('Discharge', '9', 'compound')
# ('Summary', '3', 'list')
# ('Signed', '13', 'amod')
# ('DIS', '12', 'compound')
# ('Admission', '13', 'compound')
# ('Date', '1', 'list')
# (':', '13', 'punct')
# ('DATE', '13', 'appos')
# -----------------
# ('Report', '2', 'compound')
# ('Status', '0', 'root')
# (':', '2', 'punct')
# -----------------
# ('Signed', '3', 'amod')
# ('Discharge', '3', 'compound')
# ('Date', '0', 'root')
# (':', '3', 'punct')
# ('DATE', '6', 'compound')
# ('DISCHARGE', '7', 'compound')
# ('DIAGNOSIS', '3', 'appos')
# (':', '7', 'punct')
# ('METASTATIC', '11', 'amod')
# ('CERVICAL', '11', 'amod')
# ('CARCINOMA', '7', 'appos')
# ('.', '3', 'punct')
# -----------------
# ('SECONDARY', '2', 'amod')
# ('DIAGNOSES', '3', 'nsubj')
# ('INCLUDE', '0', 'root')
# ('PERICARDIAL', '5', 'amod')
# ('EFFUSION', '3', 'obj')
# (',', '9', 'punct')
# ('PULMONARY', '9', 'compound')
# ('LYMPHANGITIC', '9', 'compound')
# ('SPREAD', '5', 'conj')
# (',', '15', 'punct')
# ('AND', '15', 'cc')
# ('LIVER', '15', 'compound')
# ('AND', '14', 'cc')
# ('SPLEEN', '12', 'conj')
# ('METASTASES', '5', 'conj')
# ('.', '3', 'punct')
# -----------------
# ('OPERATIONS', '0', 'root')
# ('AND', '3', 'cc')
# ('PROCEDURES', '1', 'conj')
# (':', '1', 'punct')
# ('Echocardiogram', '6', 'compound')
# ('times', '1', 'parataxis')
# ('two', '6', 'nummod')
# ('.', '1', 'punct')
# -----------------
# ('HISTORY', '0', 'root')
# ('OF', '4', 'case')
# ('PRESENT', '4', 'amod')
# ('ILLNESS', '1', 'nmod')
# (':', '1', 'punct')
# -----------------
# ('Patient', '8', 'nsubj')
# ('is', '8', 'cop')
# ('a', '8', 'det')
# ('28', '5', 'nummod')
# ('year', '6', 'obl:npmod')
# ('old', '8', 'amod')
# ('gravida', '8', 'compound')
# ('IV', '0', 'root')
# (',', '8', 'punct')
# ('para', '8', 'appos')
# ('2', '10', 'nummod')
# ('with', '15', 'case')
# ('metastatic', '15', 'amod')
# ('cervical', '15', 'amod')
# ('cancer', '10', 'nmod')
# ('admitted', '8', 'acl:relcl')
# ('with', '19', 'case')
# ('a', '19', 'det')
# ('question', '16', 'obl')
# ('of', '23', 'case')
# ('malignant', '23', 'amod')
# ('pericardial', '23', 'amod')
# ('effusion', '19', 'nmod')
# ('.', '8', 'punct')
# -----------------
# ('Patient', '2', 'nsubj')
# ('underwent', '0', 'root')
# ('a', '6', 'det')
# ('total', '6', 'amod')
# ('abdominal', '6', 'amod')
# ('hysterectomy', '2', 'obj')
# ('in', '8', 'case')
# ('02/90', '2', 'obl')
# ('for', '16', 'case')
# ('a', '16', 'det')
# ('4x3.6', '14', 'nummod')
# ('x', '13', 'case')
# ('2', '14', 'nummod')
# ('cm', '16', 'compound')
# ('cervical', '16', 'amod')
# ('mass', '6', 'nmod')
# ('felt', '2', 'advcl')
# ('to', '21', 'mark')
# ('be', '21', 'cop')
# ('a', '21', 'det')
# ('fibroid', '17', 'xcomp')
# ('at', '23', 'case')
# ('Vanor', '21', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Pathology', '2', 'nsubj')
# ('revealed', '0', 'root')
# ('poorly', '4', 'advmod')
# ('differentiated', '7', 'amod')
# ('squamous', '7', 'amod')
# ('cell', '7', 'compound')
# ('carcinoma', '2', 'obj')
# ('of', '10', 'case')
# ('the', '10', 'det')
# ('cervix', '7', 'nmod')
# ('with', '12', 'case')
# ('spots', '7', 'nmod')
# ('of', '15', 'case')
# ('vaginal', '15', 'amod')
# ('margins', '12', 'nmod')
# ('and', '20', 'cc')
# ('metastatic', '20', 'amod')
# ('squamous', '19', 'amod')
# ('cell', '20', 'compound')
# ('carcinoma', '15', 'conj')
# ('in', '24', 'case')
# ('the', '24', 'det')
# ('cardinal', '24', 'amod')
# ('ligaments', '20', 'nmod')
# ('with', '28', 'case')
# ('extensive', '28', 'amod')
# ('lymphatic', '28', 'amod')
# ('invasion', '24', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Patient', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('felt', '0', 'root')
# ('to', '9', 'mark')
# ('have', '9', 'cop')
# ('stage', '9', 'compound')
# ('2', '9', 'nummod')
# ('B', '9', 'compound')
# ('disease', '3', 'xcomp')
# ('and', '11', 'cc')
# ('post', '9', 'conj')
# ('-operatively', '9', 'advmod')
# (',', '3', 'punct')
# ('she', '16', 'nsubj:pass')
# ('was', '16', 'aux:pass')
# ('treated', '3', 'parataxis')
# ('with', '18', 'case')
# ('intracavitary', '16', 'obl')
# ('and', '23', 'cc')
# ('external', '18', 'conj')
# ('beam', '23', 'compound')
# ('radiation', '23', 'compound')
# ('therapy', '18', 'conj')
# ('and', '27', 'cc')
# ('low', '26', 'amod')
# ('dose', '27', 'compound')
# ('Cisplatin', '23', 'conj')
# ('.', '3', 'punct')
# -----------------
# ('On', '2', 'case')
# ('ultrasound', '9', 'obl')
# ('in', '4', 'case')
# ('02/91', '2', 'nmod')
# (',', '9', 'punct')
# ('the', '7', 'det')
# ('patient', '9', 'nsubj:pass')
# ('was', '9', 'aux:pass')
# ('found', '0', 'root')
# ('to', '11', 'mark')
# ('have', '9', 'xcomp')
# ('bilateral', '15', 'amod')
# ('cystic', '15', 'amod')
# ('adnexal', '15', 'amod')
# ('masses', '11', 'obj')
# ('confirmed', '15', 'acl')
# ('on', '19', 'case')
# ('physical', '19', 'amod')
# ('examination', '16', 'obl')
# ('.', '9', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('underwent', '0', 'root')
# ('exploratory', '4', 'amod')
# ('laparotomy', '2', 'obj')
# ('and', '6', 'cc')
# ('had', '2', 'conj')
# ('a', '11', 'det')
# ('bilateral', '11', 'amod')
# ('salpingo', '11', 'compound')
# ('-', '11', 'punct')
# ('oophorectomy', '6', 'obj')
# ('and', '13', 'cc')
# ('appendectomy', '11', 'conj')
# ('.', '2', 'punct')
# -----------------
# ('Pathology', '3', 'nsubj')
# ('was', '3', 'cop')
# ('negative', '0', 'root')
# ('for', '5', 'case')
# ('tumor', '3', 'obl')
# ('and', '7', 'cc')
# ('showed', '3', 'conj')
# ('peritubal', '11', 'amod')
# ('and', '10', 'cc')
# ('periovarian', '8', 'conj')
# ('adhesions', '7', 'obj')
# ('.', '3', 'punct')
# -----------------
# ('The', '2', 'det')
# ('patient', '4', 'nsubj')
# ('now', '4', 'advmod')
# ('presents', '0', 'root')
# ('with', '11', 'case')
# ('a', '11', 'det')
# ('three', '11', 'nummod')
# ('to', '9', 'case')
# ('four', '7', 'nmod')
# ('week', '11', 'compound')
# ('history', '4', 'obl')
# ('of', '13', 'case')
# ('shortness', '11', 'nmod')
# ('of', '15', 'case')
# ('breath', '13', 'nmod')
# ('and', '20', 'cc')
# ('a', '20', 'det')
# ('dry', '20', 'amod')
# ('non-productive', '20', 'amod')
# ('cough', '13', 'conj')
# ('.', '4', 'punct')
# -----------------
# ('She', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('evaluated', '0', 'root')
# ('by', '5', 'case')
# ('Dr.', '3', 'obl')
# ('Mielke', '5', 'flat')
# (',', '5', 'punct')
# ('a', '9', 'det')
# ('Pulmonologist', '5', 'appos')
# (',', '5', 'punct')
# ('who', '12', 'nsubj')
# ('found', '9', 'acl:relcl')
# ('her', '12', 'obj')
# ('to', '16', 'mark')
# ('be', '16', 'aux')
# ('wheezing', '12', 'xcomp')
# ('and', '18', 'cc')
# ('performed', '16', 'conj')
# ('pulmonary', '21', 'amod')
# ('function', '21', 'compound')
# ('tests', '16', 'obj')
# ('which', '23', 'nsubj')
# ('showed', '21', 'acl:relcl')
# ('an', '25', 'det')
# ('FEV1', '23', 'obj')
# ('of', '27', 'case')
# ('1.1', '25', 'nmod')
# ('and', '30', 'cc')
# ('an', '30', 'det')
# ('FVC', '25', 'conj')
# ('of', '32', 'case')
# ('1.8', '30', 'nmod')
# ('.', '3', 'punct')
# -----------------
# ('She', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('admitted', '0', 'root')
# ('to', '8', 'case')
# ('Weekscook', '6', 'compound')
# ('University', '8', 'compound')
# ('Medical', '8', 'compound')
# ('Center', '3', 'obl')
# ('with', '11', 'case')
# ('a', '11', 'det')
# ('diagnosis', '3', 'obl')
# ('of', '14', 'case')
# ('possible', '14', 'amod')
# ('asthma', '11', 'nmod')
# ('.', '3', 'punct')
# -----------------
# ('Room', '2', 'compound')
# ('air', '5', 'compound')
# ('arterial', '5', 'amod')
# ('blood', '5', 'compound')
# ('gas', '6', 'nsubj')
# ('showed', '0', 'root')
# ('a', '8', 'det')
# ('pO2', '6', 'obj')
# ('of', '10', 'case')
# ('56', '8', 'nmod')
# (',', '13', 'punct')
# ('a', '13', 'det')
# ('pCO2', '8', 'conj')
# ('of', '15', 'case')
# ('35', '13', 'nmod')
# (',', '20', 'punct')
# ('and', '20', 'cc')
# ('a', '20', 'det')
# ('p', '20', 'compound')
# ('H', '8', 'conj')
# ('of', '22', 'case')
# ('7.52', '20', 'nmod')
# ('.', '6', 'punct')
# -----------------
# ('EKG', '2', 'nsubj')
# ('showed', '0', 'root')
# ('sinus', '4', 'compound')
# ('tachycardia', '2', 'obj')
# ('at', '6', 'case')
# ('100', '9', 'obl')
# ('and', '8', 'cc')
# ('echo', '6', 'conj')
# ('revealed', '2', 'conj')
# ('pericardial', '11', 'amod')
# ('effusion', '9', 'obj')
# (',', '11', 'punct')
# ('a', '17', 'det')
# ('10', '15', 'nummod')
# ('mm', '17', 'compound')
# ('pulsus', '17', 'compound')
# ('paradoxus', '19', 'nsubj:pass')
# ('was', '19', 'aux:pass')
# ('noted', '11', 'acl:relcl')
# (',', '23', 'punct')
# ('and', '23', 'cc')
# ('no', '23', 'det')
# ('evidence', '19', 'conj')
# ('of', '25', 'case')
# ('tamponade', '23', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Given', '5', 'case')
# ('the', '5', 'det')
# ('patient', '5', 'nmod:poss')
# ("'s", '3', 'case')
# ('history', '14', 'obl')
# ('of', '8', 'case')
# ('cervical', '8', 'amod')
# ('cancer', '5', 'nmod')
# (',', '14', 'punct')
# ('the', '12', 'det')
# ('pericardial', '12', 'amod')
# ('effusion', '14', 'nsubj:pass')
# ('was', '14', 'aux:pass')
# ('felt', '0', 'root')
# ('most', '16', 'advmod')
# ('likely', '14', 'xcomp')
# ('to', '19', 'mark')
# ('be', '19', 'cop')
# ('malignant', '16', 'advcl')
# ('.', '14', 'punct')
# -----------------
# ('She', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('therefore', '4', 'advmod')
# ('transferred', '0', 'root')
# ('to', '10', 'case')
# ('the', '10', 'det')
# ('Retelk', '8', 'compound')
# ('County', '10', 'compound')
# ('Medical', '10', 'compound')
# ('Center', '4', 'obl')
# ('for', '13', 'case')
# ('further', '13', 'amod')
# ('care', '4', 'obl')
# ('.', '4', 'punct')
# -----------------
# ('PAST', '3', 'amod')
# ('MEDICAL', '3', 'amod')
# ('HISTORY', '0', 'root')
# (':', '3', 'punct')
# -----------------
# ('As', '2', 'advmod')
# ('above', '0', 'root')
# ('.', '2', 'punct')
# -----------------
# ('PAST', '3', 'amod')
# ('SURGICAL', '3', 'amod')
# ('HISTORY', '0', 'root')
# (':', '3', 'punct')
# ('02/90', '3', 'appos')
# (',', '3', 'punct')
# ('total', '9', 'amod')
# ('abdominal', '9', 'amod')
# ('hysterectomy', '3', 'appos')
# ('complicated', '9', 'acl')
# ('by', '13', 'case')
# ('ureteral', '13', 'amod')
# ('transection', '10', 'obl')
# ('with', '17', 'case')
# ('right', '17', 'amod')
# ('ureteral', '17', 'amod')
# ('tube', '13', 'nmod')
# ('placed', '17', 'acl')
# ('for', '21', 'case')
# ('six', '21', 'nummod')
# ('weeks', '18', 'obl')
# (',', '24', 'punct')
# ('stent', '24', 'compound')
# ('tube', '21', 'appos')
# ('placed', '24', 'acl')
# ('in', '28', 'case')
# ('left', '28', 'amod')
# ('ureter', '25', 'obl')
# ('six', '30', 'nummod')
# ('weeks', '25', 'obl:tmod')
# ('prior', '33', 'case')
# ('to', '31', 'fixed')
# ('admission', '25', 'obl')
# ('for', '37', 'case')
# ('a', '37', 'det')
# ('hydronephrosis', '37', 'compound')
# ('post', '33', 'nmod')
# (',', '37', 'punct')
# ('in', '40', 'case')
# ('03/91', '37', 'nmod')
# (',', '45', 'punct')
# ('bilateral', '45', 'amod')
# ('salpingo', '45', 'compound')
# ('-', '45', 'punct')
# ('oophorectomy', '37', 'conj')
# ('and', '47', 'cc')
# ('appendectomy', '45', 'conj')
# ('.', '3', 'punct')
# -----------------
# ('CURRENT', '2', 'amod')
# ('MEDICATIONS', '0', 'root')
# (':', '2', 'punct')
# ('Prednisone', '8', 'compound')
# ('20', '6', 'nummod')
# ('mg', '8', 'compound')
# ('p.o.', '8', 'compound')
# ('q.a.m.', '2', 'list')
# ('with', '13', 'case')
# ('10', '11', 'nummod')
# ('mg', '13', 'compound')
# ('p.o.', '13', 'compound')
# ('q.p.m.', '8', 'nmod')
# (',', '13', 'punct')
# ('Uniphyl', '13', 'appos')
# ('400', '17', 'nummod')
# ('mg', '2', 'list')
# ('p.o.', '2', 'list')
# ('q.d.', '2', 'list')
# (',', '19', 'punct')
# ('Augmentin', '19', 'appos')
# ('250', '21', 'compound')
# ('p.o.', '24', 'compound')
# ('t.i.d.', '2', 'list')
# (',', '24', 'punct')
# ('Estrase', '24', 'appos')
# ('2', '28', 'nummod')
# ('mg', '30', 'compound')
# ('p.o.', '30', 'compound')
# ('q.d.', '2', 'list')
# (',', '30', 'punct')
# ('MS', '30', 'appos')
# ('Contin', '30', 'appos')
# ('30', '35', 'nummod')
# ('mg', '33', 'appos')
# ('q.12', '35', 'nummod')
# ('h.', '2', 'list')
# (',', '41', 'punct')
# ('and', '41', 'cc')
# ('Morphine', '41', 'compound')
# ('p.r.n', '8', 'conj')
# ('.', '2', 'punct')
# -----------------
# ('PHYSICAL', '2', 'amod')
# ('EXAMINATION', '0', 'root')
# (':', '2', 'punct')
# ('Emaciated', '6', 'amod')
# ('white', '6', 'amod')
# ('female', '2', 'appos')
# ('in', '10', 'case')
# ('mild', '10', 'amod')
# ('respiratory', '10', 'amod')
# ('distress', '6', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Temperature', '3', 'nsubj')
# ('was', '3', 'cop')
# ('98.1', '0', 'root')
# (',', '6', 'punct')
# ('heart', '6', 'compound')
# ('rate', '3', 'appos')
# ('116', '6', 'nummod')
# (',', '10', 'punct')
# ('blood', '10', 'compound')
# ('pressure', '6', 'list')
# ('120', '12', 'compound')
# ('/68', '10', 'nummod')
# (',', '18', 'punct')
# ('and', '18', 'cc')
# ('room', '18', 'compound')
# ('air', '18', 'compound')
# ('O2', '18', 'compound')
# ('saturation', '21', 'nsubj')
# ('was', '21', 'cop')
# ('93', '21', 'nummod')
# ('%', '3', 'parataxis')
# ('.', '23', 'punct')
# ('HEENT', '3', 'parataxis')
# (':', '3', 'punct')
# -----------------
# ('Dry', '2', 'amod')
# ('mucous', '3', 'compound')
# ('membranes', '0', 'root')
# ('and', '6', 'cc')
# ('myotic', '6', 'amod')
# ('pupils', '3', 'conj')
# ('.', '3', 'punct')
# -----------------
# ('NECK', '0', 'root')
# (':', '1', 'punct')
# ('No', '4', 'det')
# ('lymphadenopathy', '1', 'appos')
# ('.', '1', 'punct')
# -----------------
# ('CHEST', '0', 'root')
# (':', '1', 'punct')
# ('Few', '5', 'amod')
# ('inspiratory', '5', 'amod')
# ('wheezes', '1', 'appos')
# ('and', '8', 'cc')
# ('no', '8', 'det')
# ('rhonchi', '5', 'conj')
# ('.', '1', 'punct')
# -----------------
# ('HEART', '0', 'root')
# (':', '1', 'punct')
# ('Regular', '4', 'amod')
# ('rate', '1', 'appos')
# ('and', '6', 'cc')
# ('rhythm', '4', 'conj')
# ('with', '8', 'case')
# ('tachycardia', '4', 'nmod')
# ('and', '11', 'cc')
# ('no', '11', 'det')
# ('rubs', '4', 'conj')
# ('or', '13', 'cc')
# ('murmur', '11', 'conj')
# ('.', '1', 'punct')
# -----------------
# ('ABDOMEN', '0', 'root')
# (':', '1', 'punct')
# ('Well', '4', 'advmod')
# ('healed', '6', 'amod')
# ('Pfannenstiel', '6', 'compound')
# ('scars', '1', 'appos')
# ('and', '9', 'cc')
# ('no', '9', 'det')
# ('masses', '6', 'conj')
# ('.', '1', 'punct')
# -----------------
# ('PELVIC', '0', 'root')
# (':', '1', 'punct')
# ('No', '4', 'det')
# ('masses', '1', 'appos')
# ('.', '1', 'punct')
# -----------------
# ('RECTAL', '0', 'root')
# (':', '1', 'punct')
# ('No', '4', 'det')
# ('masses', '1', 'appos')
# ('and', '7', 'cc')
# ('guaiac', '7', 'amod')
# ('negative', '4', 'conj')
# ('.', '1', 'punct')
# -----------------
# ('EXTREMITIES', '0', 'root')
# (':', '1', 'punct')
# ('No', '4', 'det')
# ('edema', '1', 'appos')
# ('or', '6', 'cc')
# ('cyanosis', '4', 'conj')
# ('.', '1', 'punct')
# -----------------
# ('LABORATORY', '2', 'compound')
# ('EXAMINATION', '0', 'root')
# (':', '2', 'punct')
# ('Hematocrit', '6', 'nsubj')
# ('was', '6', 'cop')
# ('40', '2', 'appos')
# (',', '9', 'punct')
# ('white', '9', 'amod')
# ('count', '11', 'nsubj')
# ('was', '11', 'cop')
# ('21', '2', 'appos')
# (',', '15', 'punct')
# ('and', '15', 'cc')
# ('platelet', '15', 'compound')
# ('count', '2', 'conj')
# ('of', '17', 'case')
# ('723,000', '15', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('PT', '5', 'nsubj')
# ('and', '3', 'cc')
# ('PTT', '1', 'conj')
# ('were', '5', 'cop')
# ('12', '0', 'root')
# ('and', '7', 'cc')
# ('26', '5', 'conj')
# ('.', '5', 'punct')
# -----------------
# ('Electrolytes', '5', 'nsubj')
# ('were', '5', 'cop')
# ('within', '5', 'case')
# ('normal', '5', 'amod')
# ('limits', '0', 'root')
# (',', '9', 'punct')
# ('liver', '8', 'compound')
# ('function', '9', 'compound')
# ('tests', '5', 'conj')
# ('within', '12', 'case')
# ('normal', '12', 'amod')
# ('limits', '9', 'nmod')
# (',', '16', 'punct')
# ('and', '16', 'cc')
# ('EKG', '16', 'nsubj')
# ('showed', '5', 'conj')
# ('a', '19', 'det')
# ('heart', '19', 'compound')
# ('rate', '16', 'obj')
# ('of', '21', 'case')
# ('128', '23', 'nummod')
# (',', '23', 'punct')
# ('axis', '19', 'appos')
# ('73', '23', 'nummod')
# (',', '29', 'punct')
# ('and', '29', 'cc')
# ('possible', '29', 'amod')
# ('ectopic', '29', 'amod')
# ('P', '19', 'conj')
# ('.', '5', 'punct')
# -----------------
# ('HOSPITAL', '2', 'compound')
# ('COURSE', '0', 'root')
# (':', '2', 'punct')
# -----------------
# ('The', '2', 'det')
# ('patient', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('admitted', '0', 'root')
# ('for', '9', 'case')
# ('a', '9', 'det')
# ('new', '9', 'amod')
# ('pericardial', '9', 'amod')
# ('effusion', '4', 'obl')
# ('which', '12', 'nsubj:pass')
# ('was', '12', 'aux:pass')
# ('felt', '9', 'acl:relcl')
# ('most', '14', 'advmod')
# ('likely', '12', 'xcomp')
# ('to', '17', 'mark')
# ('be', '17', 'cop')
# ('secondary', '14', 'advcl')
# ('to', '21', 'case')
# ('metastatic', '21', 'amod')
# ('cervical', '21', 'amod')
# ('cancer', '17', 'obl')
# ('.', '4', 'punct')
# -----------------
# ('There', '2', 'expl')
# ('was', '0', 'root')
# ('no', '4', 'det')
# ('evidence', '2', 'nsubj')
# ('of', '6', 'case')
# ('tamponade', '4', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('An', '2', 'det')
# ('echocardiogram', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('scheduled', '0', 'root')
# ('and', '8', 'cc')
# ('Cardiology', '8', 'nsubj:pass')
# ('was', '8', 'aux:pass')
# ('consulted', '4', 'conj')
# ('.', '4', 'punct')
# -----------------
# ('Echocardiogram', '2', 'nsubj')
# ('showed', '0', 'root')
# ('moderate', '6', 'amod')
# ('anterior', '6', 'amod')
# ('pericardial', '6', 'amod')
# ('effusion', '2', 'obj')
# ('of', '10', 'case')
# ('approximately', '9', 'advmod')
# ('600', '10', 'nummod')
# ('cc', '6', 'nmod')
# ('with', '13', 'case')
# ('diastolic', '13', 'amod')
# ('indications', '10', 'nmod')
# ('of', '17', 'case')
# ('the', '17', 'det')
# ('right', '17', 'amod')
# ('ventricle', '13', 'nmod')
# ('and', '21', 'cc')
# ('low', '21', 'amod')
# ('velocity', '21', 'compound')
# ('paradox', '17', 'conj')
# ('.', '2', 'punct')
# -----------------
# ('Cardiology', '4', 'nsubj')
# ('did', '4', 'aux')
# ('not', '4', 'advmod')
# ('feel', '0', 'root')
# ('that', '12', 'mark')
# ('tamponade', '12', 'nsubj')
# ('at', '9', 'case')
# ('this', '9', 'det')
# ('time', '6', 'nmod')
# ('was', '12', 'cop')
# ('a', '12', 'det')
# ('concern', '4', 'ccomp')
# ('and', '20', 'cc')
# ('that', '20', 'mark')
# ('a', '16', 'det')
# ('tap', '20', 'nsubj:pass')
# ('need', '20', 'aux')
# ('not', '20', 'advmod')
# ('be', '20', 'aux:pass')
# ('performed', '12', 'conj')
# ('.', '4', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('continued', '0', 'root')
# ('to', '4', 'mark')
# ('have', '2', 'xcomp')
# ('pulmonary', '6', 'amod')
# ('wheezing', '4', 'obj')
# (',', '9', 'punct')
# ('unknown', '9', 'amod')
# ('origin', '6', 'conj')
# (',', '4', 'punct')
# ('without', '12', 'case')
# ('history', '4', 'obl')
# ('of', '14', 'case')
# ('asthma', '12', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Her', '2', 'nmod:poss')
# ('steroids', '4', 'nsubj:pass')
# ('were', '4', 'aux:pass')
# ('tapered', '0', 'root')
# ('and', '8', 'cc')
# ('Pulmonary', '8', 'nsubj:pass')
# ('was', '8', 'aux:pass')
# ('consulted', '4', 'conj')
# ('who', '10', 'nsubj')
# ('recommended', '8', 'ccomp')
# ('a', '13', 'det')
# ('CT', '13', 'compound')
# ('scan', '10', 'obj')
# ('of', '16', 'case')
# ('the', '16', 'det')
# ('chest', '13', 'nmod')
# ('to', '18', 'mark')
# ('evaluate', '10', 'advcl')
# ('the', '21', 'det')
# ('lung', '21', 'compound')
# ('parenchyma', '18', 'obj')
# (',', '23', 'punct')
# ('induce', '18', 'conj')
# ('sputum', '23', 'obj')
# ('for', '26', 'case')
# ('CBC', '23', 'obl')
# (',', '30', 'punct')
# ('arterial', '30', 'amod')
# ('blood', '30', 'compound')
# ('gas', '26', 'conj')
# (',', '32', 'punct')
# ('continuing', '26', 'conj')
# ('of', '37', 'case')
# ('the', '37', 'det')
# ('beta', '37', 'compound')
# ('agonist', '37', 'compound')
# ('inhalers', '32', 'nmod')
# (',', '40', 'punct')
# ('and', '40', 'cc')
# ('trial', '26', 'conj')
# ('of', '43', 'case')
# ('steroid', '43', 'amod')
# ('inhalers', '40', 'nmod')
# ('.', '4', 'punct')
# -----------------
# ('They', '2', 'nsubj')
# ('felt', '0', 'root')
# ('it', '10', 'nsubj')
# ('was', '10', 'cop')
# ('most', '6', 'advmod')
# ('likely', '10', 'advmod')
# ('a', '10', 'det')
# ('malignant', '10', 'amod')
# ('lymphangitic', '10', 'compound')
# ('spread', '2', 'ccomp')
# ('with', '13', 'case')
# ('pericardial', '13', 'amod')
# ('involvement', '10', 'nmod')
# ('versus', '19', 'case')
# ('infectious', '19', 'amod')
# (',', '19', 'punct')
# ('other', '19', 'amod')
# ('cardiovascular', '19', 'compound')
# ('causes', '13', 'conj')
# (',', '23', 'punct')
# ('or', '23', 'cc')
# ('viral', '23', 'amod')
# ('bronchiolitis', '13', 'conj')
# ('.', '2', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('had', '0', 'root')
# ('pulmonary', '5', 'amod')
# ('function', '5', 'compound')
# ('tests', '2', 'obj')
# ('repeated', '5', 'acl')
# ('which', '8', 'nsubj')
# ('showed', '5', 'acl:relcl')
# ('an', '10', 'det')
# ('FEV1', '8', 'obj')
# ('of', '13', 'case')
# ('36', '13', 'nummod')
# ('%', '10', 'nmod')
# ('of', '15', 'case')
# ('predicted', '13', 'nmod')
# ('and', '17', 'cc')
# ('FVC', '15', 'conj')
# ('of', '20', 'case')
# ('56', '20', 'nummod')
# ('%', '15', 'obl')
# ('of', '22', 'case')
# ('predicted', '20', 'acl')
# ('.', '2', 'punct')
# -----------------
# ('Room', '2', 'compound')
# ('air', '5', 'compound')
# ('arterial', '5', 'amod')
# ('blood', '5', 'compound')
# ('gas', '6', 'nsubj')
# ('showed', '0', 'root')
# ('a', '8', 'det')
# ('pH', '6', 'obj')
# ('of', '10', 'case')
# ('7.45', '8', 'nmod')
# (',', '12', 'punct')
# ('pO2', '8', 'conj')
# ('of', '14', 'case')
# ('63', '12', 'nmod')
# (',', '17', 'punct')
# ('a', '17', 'det')
# ('pCO2', '8', 'conj')
# ('of', '19', 'case')
# ('41', '17', 'nmod')
# (',', '25', 'punct')
# ('and', '25', 'cc')
# ('fairly', '23', 'advmod')
# ('significant', '25', 'amod')
# ('AA', '25', 'compound')
# ('gradient', '17', 'nmod')
# ('.', '6', 'punct')
# -----------------
# ('She', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('continued', '0', 'root')
# ('on', '6', 'case')
# ('two', '6', 'nummod')
# ('liters', '3', 'obl')
# ('of', '8', 'case')
# ('oxygen', '6', 'nmod')
# ('awaiting', '6', 'acl')
# ('her', '12', 'nmod:poss')
# ('CT', '12', 'compound')
# ('scan', '9', 'obj')
# ('on', '14', 'case')
# ('06/14', '9', 'obl')
# ('and', '17', 'cc')
# ('she', '17', 'nsubj')
# ('developed', '3', 'conj')
# ('a', '21', 'det')
# ('new', '21', 'amod')
# ('junctional', '21', 'amod')
# ('rhythm', '17', 'obj')
# ('with', '24', 'case')
# ('a', '24', 'det')
# ('question', '17', 'obl')
# ('of', '28', 'case')
# ('a', '28', 'det')
# ('new', '28', 'amod')
# ('rub', '24', 'nmod')
# ('versus', '30', 'case')
# ('murmur', '28', 'nmod')
# ('on', '32', 'case')
# ('examination', '30', 'nmod')
# ('.', '3', 'punct')
# -----------------
# ('Cardiology', '2', 'nsubj')
# ('felt', '0', 'root')
# ('she', '4', 'nsubj')
# ('had', '2', 'ccomp')
# ('a', '6', 'det')
# ('rub', '4', 'obj')
# ('and', '15', 'cc')
# ('her', '9', 'nmod:poss')
# ('pulsus', '12', 'nsubj')
# ('was', '12', 'cop')
# ('still', '12', 'advmod')
# ('10', '15', 'nummod')
# ('.', '2', 'punct')
# ('EKG', '15', 'nsubj')
# ('showed', '2', 'conj')
# ('an', '20', 'det')
# ('ectopic', '20', 'amod')
# ('low', '20', 'amod')
# ('atrial', '20', 'amod')
# ('P', '15', 'obj')
# ('and', '23', 'cc')
# ('they', '23', 'nsubj')
# ('thought', '2', 'conj')
# ('she', '27', 'nsubj')
# ('was', '27', 'cop')
# ('still', '27', 'advmod')
# ('stable', '23', 'ccomp')
# ('without', '29', 'case')
# ('evidence', '27', 'obl')
# ('of', '31', 'case')
# ('tamponade', '29', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('She', '3', 'nsubj')
# ('should', '3', 'aux')
# ('have', '0', 'root')
# ('a', '8', 'det')
# ('follow', '7', 'compound')
# ('-', '7', 'punct')
# ('up', '8', 'compound')
# ('echocardiogram', '3', 'obj')
# ('.', '3', 'punct')
# -----------------
# ('Echocardiogram', '2', 'nsubj')
# ('showed', '0', 'root')
# ('left', '4', 'amod')
# ('ventricle', '2', 'obj')
# ('at', '8', 'case')
# ('the', '8', 'det')
# ('upper', '8', 'amod')
# ('limits', '2', 'obl')
# ('of', '10', 'case')
# ('normal', '8', 'nmod')
# ('for', '12', 'case')
# ('size', '10', 'obl')
# (',', '16', 'punct')
# ('low', '16', 'amod')
# ('normal', '16', 'amod')
# ('function', '8', 'conj')
# (',', '18', 'punct')
# ('moderate', '16', 'amod')
# ('to', '21', 'case')
# ('mild', '21', 'amod')
# ('effusion', '18', 'obl')
# ('with', '24', 'case')
# ('pericardial', '24', 'amod')
# ('pressures', '21', 'nmod')
# ('exceeding', '24', 'acl')
# ('right', '28', 'amod')
# ('atrial', '28', 'amod')
# ('pressures', '25', 'obj')
# (',', '33', 'punct')
# ('and', '33', 'cc')
# ('right', '33', 'amod')
# ('ventricular', '33', 'amod')
# ('pressures', '28', 'conj')
# ('at', '36', 'case')
# ('various', '36', 'amod')
# ('points', '33', 'nmod')
# ('of', '40', 'case')
# ('patient', '40', 'compound')
# ("'s", '40', 'case')
# ('cycle', '36', 'nmod')
# ('without', '43', 'case')
# ('any', '43', 'det')
# ('change', '36', 'nmod')
# ('in', '46', 'case')
# ('the', '46', 'det')
# ('effusion', '43', 'nmod')
# ('from', '48', 'case')
# ('06/11', '46', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Thoracic', '2', 'compound')
# ('Surgery', '5', 'nsubj:pass')
# ('was', '5', 'aux:pass')
# ('also', '5', 'advmod')
# ('consulted', '0', 'root')
# ('and', '8', 'cc')
# ('they', '8', 'nsubj')
# ('felt', '5', 'conj')
# ('that', '11', 'mark')
# ('there', '11', 'expl')
# ('was', '8', 'ccomp')
# ('no', '13', 'det')
# ('need', '11', 'nsubj')
# ('for', '17', 'case')
# ('a', '17', 'det')
# ('pericardial', '17', 'amod')
# ('window', '13', 'nmod')
# ('at', '20', 'case')
# ('the', '20', 'det')
# ('time', '17', 'nmod')
# ('.', '5', 'punct')
# -----------------
# ('She', '4', 'nsubj:pass')
# ('should', '4', 'aux')
# ('be', '4', 'aux:pass')
# ('continued', '0', 'root')
# ('with', '8', 'case')
# ('pulmonary', '8', 'amod')
# ('oximetry', '8', 'compound')
# ('testing', '4', 'obl')
# ('.', '4', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('underwent', '0', 'root')
# ('her', '5', 'nmod:poss')
# ('CT', '5', 'compound')
# ('scan', '2', 'obj')
# ('.', '2', 'punct')
# -----------------
# ('This', '2', 'nsubj')
# ('showed', '0', 'root')
# ('lymphangitic', '4', 'amod')
# ('spread', '2', 'obj')
# ('of', '6', 'case')
# ('cancer', '4', 'nmod')
# ('in', '9', 'case')
# ('the', '9', 'det')
# ('chest', '4', 'nmod')
# (',', '11', 'punct')
# ('question', '4', 'conj')
# ('of', '14', 'case')
# ('pulmonary', '14', 'amod')
# ('nodules', '11', 'nmod')
# ('in', '17', 'case')
# ('the', '17', 'det')
# ('chest', '11', 'nmod')
# (',', '20', 'punct')
# ('pericardial', '20', 'amod')
# ('effusion', '17', 'conj')
# (',', '24', 'punct')
# ('multiple', '24', 'amod')
# ('liver', '24', 'compound')
# ('metastases', '17', 'conj')
# (',', '27', 'punct')
# ('decreased', '27', 'amod')
# ('function', '17', 'conj')
# ('of', '31', 'case')
# ('the', '31', 'det')
# ('left', '31', 'amod')
# ('kidney', '27', 'nmod')
# (',', '37', 'punct')
# ('dilated', '37', 'amod')
# ('left', '37', 'amod')
# ('intrarenal', '37', 'amod')
# ('collecting', '37', 'compound')
# ('system', '31', 'conj')
# ('and', '40', 'cc')
# ('proximal', '40', 'amod')
# ('ureter', '31', 'conj')
# (',', '44', 'punct')
# ('and', '44', 'cc')
# ('periaortic', '44', 'amod')
# ('lymphadenopathy', '31', 'conj')
# ('.', '2', 'punct')
# -----------------
# ('Pulmonary', '2', 'nsubj')
# ('felt', '0', 'root')
# ('this', '5', 'nsubj')
# ('was', '5', 'cop')
# ('consistent', '2', 'ccomp')
# ('also', '5', 'advmod')
# ('with', '9', 'case')
# ('lymphangitic', '9', 'amod')
# ('spread', '5', 'obl')
# ('and', '14', 'cc')
# ('they', '14', 'nsubj')
# ('did', '14', 'aux')
# ('not', '14', 'advmod')
# ('feel', '2', 'conj')
# ('that', '22', 'mark')
# ('a', '17', 'det')
# ('bronchoscopy', '22', 'nsubj')
# ('would', '22', 'aux')
# ('be', '22', 'cop')
# ('of', '22', 'case')
# ('any', '22', 'det')
# ('assistance', '14', 'ccomp')
# ('at', '25', 'case')
# ('this', '25', 'det')
# ('time', '22', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('Chemotherapy', '7', 'nsubj:pass')
# ('for', '5', 'case')
# ('metastatic', '5', 'amod')
# ('cervical', '5', 'amod')
# ('cancer', '1', 'nmod')
# ('was', '7', 'aux:pass')
# ('discussed', '0', 'root')
# ('with', '10', 'case')
# ('the', '10', 'det')
# ('patient', '7', 'obl')
# ('and', '14', 'cc')
# ('she', '14', 'nsubj:pass')
# ('was', '14', 'aux:pass')
# ('started', '7', 'conj')
# ('on', '18', 'case')
# ('5', '18', 'nummod')
# ('-', '18', 'punct')
# ('FU', '20', 'compound')
# ('800', '20', 'nummod')
# ('mg', '14', 'obl')
# ('per', '22', 'case')
# ('meter', '20', 'nmod')
# ('squared', '24', 'amod')
# ('days', '14', 'obl')
# ('06/18', '24', 'nummod')
# (',', '27', 'punct')
# ('06/19', '25', 'nummod')
# (',', '30', 'punct')
# ('and', '30', 'cc')
# ('06/20', '25', 'conj')
# ('.', '7', 'punct')
# -----------------
# ('She', '3', 'nsubj')
# ('also', '3', 'advmod')
# ('received', '0', 'root')
# ('Cisplatin', '3', 'obj')
# ('35', '4', 'nummod')
# ('per', '7', 'case')
# ('meter', '5', 'nmod')
# ('squared', '4', 'acl')
# ('on', '10', 'case')
# ('06/19', '8', 'obl')
# ('and', '12', 'cc')
# ('Ifex', '10', 'conj')
# ('and', '14', 'cc')
# ('Mesna', '10', 'conj')
# ('on', '16', 'case')
# ('06/18', '3', 'obl')
# ('.', '3', 'punct')
# -----------------
# ('She', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('noted', '0', 'root')
# (',', '3', 'punct')
# ('on', '6', 'case')
# ('06/16', '3', 'obl')
# (',', '3', 'punct')
# ('to', '9', 'mark')
# ('have', '3', 'advcl')
# ('numerous', '12', 'amod')
# ('erythematous', '12', 'amod')
# ('maculopapules', '9', 'obj')
# ('on', '15', 'case')
# ('her', '15', 'nmod:poss')
# ('back', '9', 'obl')
# ('and', '17', 'cc')
# ('chest', '15', 'conj')
# ('.', '3', 'punct')
# -----------------
# ('Dermatology', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('consulted', '0', 'root')
# ('and', '6', 'cc')
# ('they', '6', 'nsubj')
# ('felt', '3', 'conj')
# ('that', '13', 'mark')
# ('this', '13', 'nsubj')
# ('was', '13', 'cop')
# ('most', '11', 'advmod')
# ('likely', '13', 'advmod')
# ('steroid', '13', 'amod')
# ('acne', '6', 'ccomp')
# ('.', '3', 'punct')
# -----------------
# ('They', '3', 'nsubj')
# ('therefore', '3', 'advmod')
# ('felt', '0', 'root')
# ('a', '7', 'det')
# ('rapid', '7', 'amod')
# ('steroid', '7', 'compound')
# ('taper', '9', 'nsubj:pass')
# ('was', '9', 'aux:pass')
# ('indicated', '3', 'ccomp')
# ('and', '12', 'cc')
# ('topical', '12', 'amod')
# ('Erythromycin', '9', 'conj')
# ('if', '14', 'mark')
# ('desired', '9', 'advcl')
# ('by', '17', 'case')
# ('the', '17', 'det')
# ('patient', '14', 'obl')
# ('.', '3', 'punct')
# -----------------
# ('The', '2', 'det')
# ('patient', '4', 'nmod:poss')
# ("'s", '2', 'case')
# ('shortness', '9', 'nsubj')
# ('of', '6', 'case')
# ('breath', '4', 'nmod')
# ('and', '8', 'cc')
# ('wheezing', '6', 'conj')
# ('continued', '0', 'root')
# ('but', '12', 'cc')
# ('without', '12', 'case')
# ('change', '9', 'conj')
# ('.', '9', 'punct')
# -----------------
# ('Her', '3', 'nmod:poss')
# ('cardiac', '3', 'amod')
# ('examination', '4', 'nsubj')
# ('remained', '0', 'root')
# ('the', '6', 'det')
# ('same', '4', 'obj')
# ('and', '9', 'cc')
# ('there', '9', 'expl')
# ('continued', '4', 'conj')
# ('to', '13', 'mark')
# ('be', '13', 'cop')
# ('no', '13', 'det')
# ('evidence', '9', 'xcomp')
# ('of', '15', 'case')
# ('tamponade', '13', 'nmod')
# ('.', '4', 'punct')
# -----------------
# ('Cardiology', '2', 'nsubj')
# ('felt', '0', 'root')
# ('that', '9', 'mark')
# ('follow', '7', 'compound')
# ('-', '4', 'punct')
# ('up', '4', 'compound:prt')
# ('echo', '9', 'nsubj:pass')
# ('was', '9', 'aux:pass')
# ('indicated', '2', 'ccomp')
# ('on', '11', 'case')
# ('06/18', '9', 'obl')
# ('as', '14', 'mark')
# ('she', '14', 'nsubj')
# ('had', '9', 'advcl')
# ('another', '16', 'det')
# ('echocardiogram', '14', 'obj')
# ('which', '18', 'nsubj')
# ('showed', '16', 'acl:relcl')
# ('no', '20', 'det')
# ('change', '18', 'obj')
# ('or', '22', 'cc')
# ('evidence', '20', 'conj')
# ('of', '24', 'case')
# ('tamponade', '22', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('They', '3', 'nsubj')
# ('therefore', '3', 'advmod')
# ('felt', '0', 'root')
# ('that', '8', 'mark')
# ('she', '8', 'nsubj:pass')
# ('could', '8', 'aux')
# ('be', '8', 'aux:pass')
# ('continued', '3', 'ccomp')
# ('to', '11', 'mark')
# ('be', '11', 'aux:pass')
# ('followed', '8', 'xcomp')
# ('by', '13', 'case')
# ('examination', '11', 'obl')
# ('.', '3', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('had', '0', 'root')
# ('some', '6', 'det')
# ('mental', '6', 'amod')
# ('status', '6', 'compound')
# ('changes', '2', 'obj')
# ('with', '8', 'case')
# ('confusion', '6', 'nmod')
# ('and', '10', 'cc')
# ('hallucinations', '8', 'conj')
# ('on', '12', 'case')
# ('06/18', '2', 'obl')
# ('originating', '6', 'acl')
# ('from', '15', 'case')
# ('narcotics', '13', 'obl')
# ('versus', '19', 'case')
# ('decreased', '19', 'amod')
# ('p', '19', 'compound')
# ('O2', '15', 'nmod')
# ('.', '2', 'punct')
# -----------------
# ('The', '2', 'det')
# ('Ifex', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('held', '0', 'root')
# ('as', '8', 'mark')
# ('it', '8', 'nsubj:pass')
# ('was', '8', 'aux:pass')
# ('felt', '4', 'advcl')
# ('that', '13', 'mark')
# ('it', '13', 'nsubj')
# ('could', '13', 'aux')
# ('have', '13', 'aux')
# ('precipitated', '8', 'ccomp')
# ('the', '17', 'det')
# ('mental', '17', 'amod')
# ('status', '17', 'compound')
# ('changes', '13', 'obj')
# ('and', '21', 'cc')
# ('that', '21', 'mark')
# ('she', '21', 'nsubj')
# ('was', '13', 'conj')
# ('to', '23', 'mark')
# ('receive', '21', 'xcomp')
# ('no', '26', 'det')
# ('further', '26', 'amod')
# ('Ifex', '23', 'obj')
# ('.', '4', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('had', '0', 'root')
# ('no', '5', 'det')
# ('further', '5', 'amod')
# ('hallucinations', '2', 'obj')
# ('since', '7', 'mark')
# ('stopping', '2', 'advcl')
# ('the', '9', 'det')
# ('Ifex', '7', 'obj')
# ('.', '2', 'punct')
# -----------------
# ('Psychiatry', '4', 'nsubj:pass')
# ('was', '4', 'aux:pass')
# ('also', '4', 'advmod')
# ('consulted', '0', 'root')
# ('to', '6', 'mark')
# ('help', '4', 'xcomp')
# ('her', '6', 'obj')
# ('with', '10', 'case')
# ('the', '10', 'det')
# ('changes', '6', 'obl')
# ('she', '13', 'nsubj')
# ('was', '13', 'aux')
# ('feeling', '10', 'acl:relcl')
# ('since', '17', 'case')
# ('her', '17', 'nmod:poss')
# ('new', '17', 'amod')
# ('diagnosis', '13', 'obl')
# ('.', '4', 'punct')
# -----------------
# ('She', '3', 'nsubj:pass')
# ('was', '3', 'aux:pass')
# ('hooked', '0', 'root')
# ('up', '3', 'compound:prt')
# ('with', '7', 'case')
# ('support', '7', 'compound')
# ('services', '3', 'obl')
# ('in', '10', 'case')
# ('Collot', '10', 'compound')
# ('Ln', '7', 'nmod')
# (',', '12', 'punct')
# ('Dugo', '10', 'conj')
# (',', '14', 'punct')
# ('Indiana', '10', 'conj')
# ('68961', '10', 'list')
# ('for', '18', 'case')
# ('further', '18', 'amod')
# ('counselling', '3', 'obl')
# ('and', '20', 'cc')
# ('given', '18', 'conj')
# ('Xanax', '20', 'obj')
# ('for', '23', 'case')
# ('symptoms', '20', 'obl')
# ('of', '25', 'case')
# ('anxiety', '23', 'nmod')
# ('.', '3', 'punct')
# -----------------
# ('She', '2', 'nsubj')
# ('continued', '0', 'root')
# ('to', '4', 'mark')
# ('have', '2', 'xcomp')
# ('no', '6', 'det')
# ('change', '4', 'obj')
# ('in', '9', 'case')
# ('her', '9', 'nmod:poss')
# ('shortness', '6', 'nmod')
# ('of', '11', 'case')
# ('breath', '9', 'nmod')
# ('or', '14', 'cc')
# ('cardiac', '14', 'amod')
# ('examination', '11', 'conj')
# ('and', '17', 'cc')
# ('was', '17', 'aux:pass')
# ('discharged', '2', 'conj')
# ('home', '17', 'advmod')
# ('on', '20', 'case')
# ('DATE', '17', 'obl')
# ('after', '22', 'mark')
# ('completing', '17', 'advcl')
# ('her', '29', 'nmod:poss')
# ('5', '26', 'nummod')
# ('-', '26', 'punct')
# ('FU', '22', 'obj')
# ('and', '28', 'cc')
# ('Cisplatin', '26', 'conj')
# ('chemotherapy', '22', 'obj')
# ('.', '2', 'punct')
# -----------------
# ('DISPOSITION', '0', 'root')
# (':', '1', 'punct')
# ('She', '6', 'nsubj:pass')
# ('will', '6', 'aux')
# ('be', '6', 'aux:pass')
# ('followed', '1', 'appos')
# ('by', '8', 'case')
# ('Dr.', '6', 'obl')
# ('Mielke', '8', 'flat')
# ('and', '13', 'cc')
# ('home', '12', 'compound')
# ('care', '13', 'compound')
# ('services', '8', 'conj')
# ('.', '1', 'punct')
# -----------------
# ('DISCHARGE', '2', 'compound')
# ('MEDICATIONS', '0', 'root')
# (':', '2', 'punct')
# ('Premarin', '2', 'appos')
# ('0.625', '6', 'compound')
# ('q.d.', '4', 'list')
# (',', '6', 'punct')
# ('Proventil', '9', 'compound')
# ('Inhaler', '4', 'conj')
# ('two', '12', 'nummod')
# ('puffs', '12', 'compound')
# ('q.i.d.', '4', 'list')
# (',', '12', 'punct')
# ('Beclovent', '12', 'appos')
# ('four', '16', 'nummod')
# ('puffs', '2', 'list')
# ('b.i.d.', '4', 'conj')
# (',', '4', 'punct')
# ('Colace', '4', 'conj')
# ('100', '19', 'nummod')
# ('mg', '22', 'compound')
# ('p.o.', '4', 'conj')
# ('t.i.d.', '4', 'conj')
# (',', '4', 'punct')
# ('MS', '26', 'compound')
# ('Contin', '4', 'conj')
# ('30', '29', 'nummod')
# ('mg', '29', 'compound')
# ('p.o.', '4', 'conj')
# ('t.i.d.', '4', 'conj')
# (',', '30', 'punct')
# ('Elavil', '4', 'conj')
# ('25', '34', 'nummod')
# ('mg', '35', 'compound')
# ('p.o.', '4', 'conj')
# ('q.h.s.', '4', 'conj')
# (',', '36', 'punct')
# ('Trilisate', '36', 'appos')
# ('750', '40', 'compound')
# ('mg', '41', 'compound')
# ('p.o.', '4', 'conj')
# ('b.i.d.', '4', 'conj')
# (',', '42', 'punct')
# ('MS', '45', 'compound')
# ('Elixir', '4', 'conj')
# ('100', '45', 'nummod')
# ('mg', '48', 'compound')
# ('p.o.', '4', 'conj')
# ('q.2h.', '48', 'appos')
# ('p.r.n.', '4', 'conj')
# (',', '52', 'punct')
# ('Robitussin', '4', 'conj')
# ('with', '54', 'case')
# ('Codeine', '58', 'compound')
# ('5', '58', 'nummod')
# ('cc', '58', 'compound')
# ('p.o.', '58', 'compound')
# ('q.2h.', '4', 'conj')
# (',', '62', 'punct')
# ('and', '62', 'cc')
# ('home', '62', 'compound')
# ('O2', '4', 'conj')
# ('two', '64', 'nummod')
# ('liters', '4', 'conj')
# ('via', '67', 'case')
# ('nasal', '67', 'amod')
# ('prong', '64', 'nmod')
# ('with', '69', 'case')
# ('increase', '64', 'nmod')
# ('to', '72', 'case')
# ('four', '72', 'nummod')
# ('liters', '69', 'nmod')
# ('as', '74', 'mark')
# ('needed', '69', 'acl')
# ('for', '76', 'case')
# ('symptoms', '74', 'obl')
# ('p.r.n.', '74', 'obl')
# ('ZQ233/5272', '77', 'appos')
# ('EARLLAMARG', '78', 'appos')
# -----------------
# ('S.', '0', 'root')
# ('MIELKE', '1', 'flat')
# (',', '1', 'punct')
# ('M.D.', '1', 'flat')
# ('RP75', '6', 'compound')
# ('D', '1', 'list')
# (':', '1', 'punct')
# ('DATE', '9', 'compound')
# ('Batch', '1', 'list')
# (':', '9', 'punct')
# ('8600', '9', 'appos')
# ('Report', '1', 'list')
# (':', '12', 'punct')
# ('J4678A87', '12', 'appos')
# ('T', '1', 'list')
# (':', '15', 'punct')
# ('DATE', '18', 'compound')
# ('Dicatated', '15', 'appos')
# -----------------
# ('By', '3', 'case')
# (':', '3', 'punct')
# ('SONRELLE', '0', 'root')
# ('LOUELLPASCGACH', '3', 'flat')
# (',', '3', 'punct')
# ('M.D.', '3', 'flat')
# ('EH41', '3', 'flat')
# -----------------

# %%
def analyse_deps(sentence):
    dependencies = list()
    for word in sentence.words:
        if word.governor == 0:
            dependencies.append(['root', word.text])
        else:
            dependencies.append([word.governor-1, word.text])
    return dependencies

###now: try to extract sentences where concept is present -> put this into pipeline!!

# %%
with open('combined_diseases2.csv') as csvfile:
    csvdata = csv.reader(csvfile)
    next(csvdata, None)
    conc_beginning = []
    conc_end = []
    range_txt = []
    concept = []
    for row in csvdata:
        conc_beginning.append(int(row[12]))
        conc_end.append(int(row[11]))
        range_txt.append(row[13])
        concept.append(row[3])

def get_sentence(range_txt, conc_beginning, conc_end):
    all_sent = list()
    txt_length = 0
    sentence_h = list()
    for i, sent in enumerate(doc.sentences):
        for word in sent.words:
            if conc_beginning <= txt_length <= conc_end:
                return i, sent
            txt_length += len(word.text) + 1
    return 0
    

    
def get_word_dependents(doc, range_txt, conc_beginning, conc_end):
        index = get_sentence(range_txt, conc_beginning, conc_end)
        depend = analyse_deps(doc.sentences[index])
        words = [word.text for word in doc.sentences[index].words]
        pos = [word.pos for word in doc.sentences[index].words]
        range_words = range_txt.split(' ')
        for i in range(len(words)):
            flag = 0
            for j in range(len(range_words)):
                if range_words[j].lower() == words[i+j].lower():
                    flag += 1
                    if flag >= len(range_words):
                        dep_indices = [k for k, value in enumerate(depend) if value[0] in range(i,i+j+1)]
                        dep_indices2 = [depend[k][0] for k in range (i,i+j+1)]
                        dep_indices += dep_indices2
                        return [[words[l] for l in dep_indices if words[l] not in range_words], [pos[l] for l in dep_indices if words[l] not in range_words]]

dependents = list()
for i in range(len(range_txt)):
    dependents.append((range_txt[i], get_word_dependents(doc, range_txt[i], conc_beginning[i], conc_end[i])))
    
print(dependents)

for dependent in dependents:
    if dependent[1] is None:
        continue
    removal = list()
    for i, (wrd, pos) in enumerate(zip(dependent[1][0], dependent[1][1])):
        if pos in ['VBD', 'VB', 'VBG', 'VBP', 'VBN','EX', 'CC', 'HYPH', '.', ',', 'LS', 'PRP', 'PRP$', 'WDT', 'WP', 'WP$', 'WRB']:
            removal.append([wrd,pos])
        elif wrd.lower() in STOP_WORDS:
            removal.append([wrd,pos])
    for j in removal:
        dependent[1][0].remove(j[0])
        dependent[1][1].remove(j[1])
        
            
for dependent in dependents:
    print('Word:', dependent[0], '\t- Dependents:', dependent[1])

##chunking
# Out:
# [('DIS', [['Admission'], ['NN']]), ('METASTATIC CERVICAL CARCINOMA', [['DIAGNOSIS'], ['NN']]), ('PERICARDIAL EFFUSION', [['SPREAD', 'METASTASES', 'INCLUDE'], ['NN', 'NNS', 'VBP']]), ('LIVER AND SPLEEN METASTASES', [[',', 'EFFUSION'], [',', 'NN']]), ('metastatic cervical cancer', [['with', 'para'], ['IN', 'NN']]), ('malignant pericardial effusion', [['of', 'question'], ['IN', 'NN']]), ('fibroid', None), ('poorly differentiated squamous cell carcinoma', [['cervix', 'spots', 'revealed'], ['NN', 'NNS', 'VBD']]), ('metastatic squamous cell carcinoma', [['and', 'ligaments', 'margins'], ['CC', 'NNS', 'NNS']]), ('tumor', [['for', 'negative'], ['IN', 'JJ']]), ('asthma', None), ('sinus tachycardia', [['showed'], ['VBD']]), ('pericardial effusion', [[',', 'noted', 'revealed'], [',', 'VBN', 'VBD']]), ('cervical cancer', [['of', 'history'], ['IN', 'NN']]), ('pericardial effusion', [['the', 'felt'], ['DT', 'VBN']]), ('hydronephrosis', [['post'], ['NN']]), ('pericardial effusion', [['for', 'a', 'new', 'felt', 'admitted'], ['IN', 'DT', 'JJ', 'VBN', 'VBN']]), ('metastatic cervical cancer', [['to', 'secondary'], ['IN', 'JJ']]), ('anterior', [['effusion'], ['NN']]), ('pericardial effusion', [['moderate', 'anterior', 'cc', 'showed'], ['JJ', 'JJ', 'NN', 'VBD']]), ('asthma', None), ('infectious', [['causes'], ['NNS']]), ('bronchiolitis', [[',', 'or', 'viral', 'involvement'], [',', 'CC', 'JJ', 'NN']]), ('effusion with pericardial', [['to', 'mild', 'pressures', 'moderate', 'pressures', 'pressures'], ['IN', 'JJ', 'NNS', 'JJ', 'NNS', 'NNS']]), ('cancer', [['of', 'spread'], ['IN', 'NN']]), ('nodules', [['of', 'pulmonary', 'question'], ['IN', 'JJ', 'NN']]), ('pericardial effusion', [[',', 'chest'], [',', 'NN']]), ('liver metastases', [[',', 'multiple', 'chest'], [',', 'JJ', 'NN']]), ('metastatic cervical cancer', [['for', 'Chemotherapy'], ['IN', 'NN']]), ('steroid acne', [['that', 'this', 'was', 'likely', 'felt'], ['IN', 'DT', 'VBD', 'RB', 'VBD']]), ('confusion', None), ('hallucinations', [['and', 'confusion'], ['CC', 'NN']]), ('hallucinations', [['no', 'further', 'had'], ['DT', 'JJ', 'VBD']]), ('anxiety', None)]
# Word: DIS 	- Dependents: [['Admission'], ['NN']]
# Word: METASTATIC CERVICAL CARCINOMA 	- Dependents: [['DIAGNOSIS'], ['NN']]
# Word: PERICARDIAL EFFUSION 	- Dependents: [['SPREAD', 'METASTASES'], ['NN', 'NNS']]
# Word: LIVER AND SPLEEN METASTASES 	- Dependents: [['EFFUSION'], ['NN']]
# Word: metastatic cervical cancer 	- Dependents: [['para'], ['NN']]
# Word: malignant pericardial effusion 	- Dependents: [['question'], ['NN']]
# Word: fibroid 	- Dependents: None
# Word: poorly differentiated squamous cell carcinoma 	- Dependents: [['cervix', 'spots'], ['NN', 'NNS']]
# Word: metastatic squamous cell carcinoma 	- Dependents: [['ligaments', 'margins'], ['NNS', 'NNS']]
# Word: tumor 	- Dependents: [['negative'], ['JJ']]
# Word: asthma 	- Dependents: None
# Word: sinus tachycardia 	- Dependents: [[], []]
# Word: pericardial effusion 	- Dependents: [[], []]
# Word: cervical cancer 	- Dependents: [['history'], ['NN']]
# Word: pericardial effusion 	- Dependents: [[], []]
# Word: hydronephrosis 	- Dependents: [['post'], ['NN']]
# Word: pericardial effusion 	- Dependents: [['new'], ['JJ']]
# Word: metastatic cervical cancer 	- Dependents: [['secondary'], ['JJ']]
# Word: anterior 	- Dependents: [['effusion'], ['NN']]
# Word: pericardial effusion 	- Dependents: [['moderate', 'anterior', 'cc'], ['JJ', 'JJ', 'NN']]
# Word: asthma 	- Dependents: None
# Word: infectious 	- Dependents: [['causes'], ['NNS']]
# Word: bronchiolitis 	- Dependents: [['viral', 'involvement'], ['JJ', 'NN']]
# Word: effusion with pericardial 	- Dependents: [['mild', 'pressures', 'moderate', 'pressures', 'pressures'], ['JJ', 'NNS', 'JJ', 'NNS', 'NNS']]
# Word: cancer 	- Dependents: [['spread'], ['NN']]
# Word: nodules 	- Dependents: [['pulmonary', 'question'], ['JJ', 'NN']]
# Word: pericardial effusion 	- Dependents: [['chest'], ['NN']]
# Word: liver metastases 	- Dependents: [['multiple', 'chest'], ['JJ', 'NN']]
# Word: metastatic cervical cancer 	- Dependents: [['Chemotherapy'], ['NN']]
# Word: steroid acne 	- Dependents: [['likely'], ['RB']]
# Word: confusion 	- Dependents: None
# Word: hallucinations 	- Dependents: [['confusion'], ['NN']]
# Word: hallucinations 	- Dependents: [['no'], ['DT']]
# Word: anxiety 	- Dependents: None
